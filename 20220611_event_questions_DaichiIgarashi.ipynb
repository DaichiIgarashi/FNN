# %% [markdown]
# <a href="https://colab.research.google.com/github/DaichiIgarashi/FNN/blob/main/20220611_event_questions_DaichiIgarashi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 問題１：FizzBuzz問題

# %%
for num in range(1, 101):
    string = ''

    # ここから記述

    # 15の倍数でFizzBuzzを出力
    if num % 15 == 0:
      print('FizzBuzz')

    # 3の倍数でFizzを出力
    elif num % 3 == 0: 
      print('Fizz')
    
    # 5の倍数でBuzzを出力
    elif num % 5 == 0:
      print('Buzz')
    
    
    
    # その他の場合数字を出力
    else:
      print(num)
    
    # ここまで記述

    print(string)
# Out:
# 1
#
# 2
#
# Fizz
#
# 4
#
# Buzz
#
# Fizz
#
# 7
#
# 8
#
# Fizz
#
# Buzz
#
# 11
#
# Fizz
#
# 13
#
# 14
#
# FizzBuzz
#
# 16
#
# 17
#
# Fizz
#
# 19
#
# Buzz
#
# Fizz
#
# 22
#
# 23
#
# Fizz
#
# Buzz
#
# 26
#
# Fizz
#
# 28
#
# 29
#
# FizzBuzz
#
# 31
#
# 32
#
# Fizz
#
# 34
#
# Buzz
#
# Fizz
#
# 37
#
# 38
#
# Fizz
#
# Buzz
#
# 41
#
# Fizz
#
# 43
#
# 44
#
# FizzBuzz
#
# 46
#
# 47
#
# Fizz
#
# 49
#
# Buzz
#
# Fizz
#
# 52
#
# 53
#
# Fizz
#
# Buzz
#
# 56
#
# Fizz
#
# 58
#
# 59
#
# FizzBuzz
#
# 61
#
# 62
#
# Fizz
#
# 64
#
# Buzz
#
# Fizz
#
# 67
#
# 68
#
# Fizz
#
# Buzz
#
# 71
#
# Fizz
#
# 73
#
# 74
#
# FizzBuzz
#
# 76
#
# 77
#
# Fizz
#
# 79
#
# Buzz
#
# Fizz
#
# 82
#
# 83
#
# Fizz
#
# Buzz
#
# 86
#
# Fizz
#
# 88
#
# 89
#
# FizzBuzz
#
# 91
#
# 92
#
# Fizz
#
# 94
#
# Buzz
#
# Fizz
#
# 97
#
# 98
#
# Fizz
#
# Buzz

# %% [markdown]
# 問題2：探索アルゴリズムの実装

# %%
def main():
    # 昇順にソートされた配列
    sorted_array = [1, 2, 3, 5, 12, 7890, 12345]
    # 探索対象の番号
    target_number = 7890
    # 探索実行
    target_index = serch_index(sorted_array, target_number)
    # 結果出力
    print(target_index)

def serch_index(sorted_array, target_number):

    # ここから記述

    # 検索対象の番号を取得
    target_index = len(sorted_array)//2

    # 探索対象と中間の値が一致するまで繰り返す
    while sorted_array[len(sorted_array)//2] != target_number:

      # 探索対象が中間の値より小さい場合の処理
      if target_number < sorted_array[len(sorted_array)//2]:
        sorted_array = sorted_array[0 : len(sorted_array)//2]
        target_index -= len(sorted_array)//2 - 1

      # 探索対象が中間の値より大きい場合の処理
      elif target_number > sorted_array[len(sorted_array)//2]:
        sorted_array = sorted_array[len(sorted_array)//2+1 : len(sorted_array)]
        target_index += len(sorted_array)//2 + 1
        
    # 検索対象の番号を返す
    return target_index

    # ここまで記述

    # 探索対象が存在しない場合、-1を返却
    return -1

if __name__ == '__main__':
    main()
# Out:
# 5
